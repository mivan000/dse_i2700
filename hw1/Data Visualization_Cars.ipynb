# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
raw_data = 'http://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data'
cols_link = 'http://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.names'

# %%
columns = ['symboling',
'normalized-losses',
'make',
'fuel-type',
'aspiration',
'num-of-doors',
'body-style',
'drive-wheels',
'engine-location',
'wheel-base',
'length',
'width',
'height',
'curb-weight',
'engine-type',
'num-of-cylinders',
'engine-size',
'fuel-system',
'bore',
'stroke',
'compression-ratio',
'horsepower',
'peak-rpm',
'city-mpg',
'highway-mpg',
'price']

# %%
cars = pd.read_csv(raw_data, na_values='?', names = columns)

# %%
cars.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
cars.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
cars.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# cars.fillna('', inplace=True)

# %%
cars['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
mapping = {'four': 4, 'six': 6, 'five': 5, 'three': 3, 'twelve': 12, 'two': 2, 'eight': 8}

# %%
cars['num-of-cylinders-numerical'] = cars['num-of-cylinders'].replace(mapping)

# %%
cars[['num-of-cylinders','num-of-cylinders-numerical']]
# Out:
#     num-of-cylinders  num-of-cylinders-numerical
# 0               four                           4
# 1               four                           4
# 2                six                           6
# 3               four                           4
# 4               five                           5
# ..               ...                         ...
# 200             four                           4
# 201             four                           4
# 202              six                           6
# 203              six                           6
# 204             four                           4
#
# [205 rows x 2 columns]

# %%
cars.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'num-of-cylinders-numerical'],
#       dtype='object')

# %%
cars_vega = cars[['make', 'fuel-type', 'body-style', 'drive-wheels','curb-weight', 'engine-type',
       'num-of-cylinders', 'num-of-cylinders-numerical', 'engine-size', 'horsepower','city-mpg', 'highway-mpg', 'price']]

# %%
# columns wiht null values
cars_null = cars_vega[cars_vega.isnull().values]
cars_null
# Out:
#         make fuel-type body-style drive-wheels  curb-weight engine-type  \
# 9       audi       gas  hatchback          4wd         3053         ohc
# 44     isuzu       gas      sedan          fwd         1874         ohc
# 45     isuzu       gas      sedan          fwd         1909         ohc
# 129  porsche       gas  hatchback          rwd         3366       dohcv
# 130  renault       gas      wagon          fwd         2579         ohc
# 131  renault       gas  hatchback          fwd         2460         ohc
#
#     num-of-cylinders  num-of-cylinders-numerical  engine-size  horsepower  \
# 9               five                           5          131       160.0
# 44              four                           4           90        70.0
# 45              four                           4           90        70.0
# 129            eight                           8          203       288.0
# 130             four                           4          132         NaN
# ...

# %%
# flagging rows with nulls
cars_vega_w_null = cars_vega[~cars_vega.isin(cars_null)]
cars_vega_w_null
# Out:
#             make fuel-type   body-style drive-wheels  curb-weight engine-type  \
# 0    alfa-romero       gas  convertible          rwd       2548.0        dohc
# 1    alfa-romero       gas  convertible          rwd       2548.0        dohc
# 2    alfa-romero       gas    hatchback          rwd       2823.0        ohcv
# 3           audi       gas        sedan          fwd       2337.0         ohc
# 4           audi       gas        sedan          4wd       2824.0         ohc
# ..           ...       ...          ...          ...          ...         ...
# 200        volvo       gas        sedan          rwd       2952.0         ohc
# 201        volvo       gas        sedan          rwd       3049.0         ohc
# 202        volvo       gas        sedan          rwd       3012.0        ohcv
# 203        volvo    diesel        sedan          rwd       3217.0         ohc
# 204        volvo       gas        sedan          rwd       3062.0         ohc
#
# ...

# %%
cars_vega_no_null = cars_vega_w_null.dropna()
cars_vega_no_null
# Out:
#             make fuel-type   body-style drive-wheels  curb-weight engine-type  \
# 0    alfa-romero       gas  convertible          rwd       2548.0        dohc
# 1    alfa-romero       gas  convertible          rwd       2548.0        dohc
# 2    alfa-romero       gas    hatchback          rwd       2823.0        ohcv
# 3           audi       gas        sedan          fwd       2337.0         ohc
# 4           audi       gas        sedan          4wd       2824.0         ohc
# ..           ...       ...          ...          ...          ...         ...
# 200        volvo       gas        sedan          rwd       2952.0         ohc
# 201        volvo       gas        sedan          rwd       3049.0         ohc
# 202        volvo       gas        sedan          rwd       3012.0        ohcv
# 203        volvo    diesel        sedan          rwd       3217.0         ohc
# 204        volvo       gas        sedan          rwd       3062.0         ohc
#
# ...

# %%
cars_vega_no_null.isna().sum()
# Out:
# make                          0
# fuel-type                     0
# body-style                    0
# drive-wheels                  0
# curb-weight                   0
# engine-type                   0
# num-of-cylinders              0
# num-of-cylinders-numerical    0
# engine-size                   0
# horsepower                    0
# city-mpg                      0
# highway-mpg                   0
# price                         0
# dtype: int64

# %%
cars_vega_no_null.to_csv('cars_parallel.csv', index = False)

# %%
# export for most 
cars_vega.to_csv('cars_clean.csv', index = False)

# %%
cars_vega.to_csv('cars_clean.csv', index = False)

# %%
cars_imported = pd.read_csv('https://raw.githubusercontent.com/mivan000/dse_i2700/main/hw1/cars_clean.csv')

# %%
plt.scatter(cars_imported['engine-size'],cars_imported['horsepower'])

# %%
plt.bar(cars_imported['body-style'],cars_imported['engine-size'])
plt.bar(cars_imported['body-style'],cars_imported['price'])
plt.show()
